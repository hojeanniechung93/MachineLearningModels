# %%
import pandas as pd

# %%
# We will make more sense of these two lines in the read_csv video
oo = pd.read_csv("../../Desktop/Data/olympics.csv")
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## Accessing the DataFrame

# %%
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
oo["City"]
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29186    Beijing
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# ...

# %%
oo.Athlete
# Out:
# 0                      HAJOS, Alfred
# 1                   HERSCHMANN, Otto
# 2                  DRIVAS, Dimitrios
# 3                 MALOKINIS, Ioannis
# 4                 CHASAPIS, Spiridon
# 5              CHOROPHAS, Efstathios
# 6                      HAJOS, Alfred
# 7                   ANDREOU, Joannis
# 8              CHOROPHAS, Efstathios
# 9                      NEUMANN, Paul
# 10                 PEPANOS, Antonios
# 11                     LANE, Francis
# 12                  SZOKOLYI, Alajos
# 13                     BURKE, Thomas
# 14                    HOFMANN, Fritz
# 15                    CURTIS, Thomas
# 16                GOULDING, Grantley
# 17                 LERMUSIAUX, Albin
# 18                      FLACK, Edwin
# 19                     BLAKE, Arthur
# 20                   GMELIN, Charles
# 21                     BURKE, Thomas
# 22                  JAMISON, Herbert
# 23                GOLEMIS, Dimitrios
# 24                      FLACK, Edwin
# ...

# %%
oo[["City","Athlete"]]
# Out:
#           City                      Athlete
# 0       Athens                HAJOS, Alfred
# 1       Athens             HERSCHMANN, Otto
# 2       Athens            DRIVAS, Dimitrios
# 3       Athens           MALOKINIS, Ioannis
# 4       Athens           CHASAPIS, Spiridon
# 5       Athens        CHOROPHAS, Efstathios
# 6       Athens                HAJOS, Alfred
# 7       Athens             ANDREOU, Joannis
# 8       Athens        CHOROPHAS, Efstathios
# 9       Athens                NEUMANN, Paul
# 10      Athens            PEPANOS, Antonios
# 11      Athens                LANE, Francis
# 12      Athens             SZOKOLYI, Alajos
# 13      Athens                BURKE, Thomas
# 14      Athens               HOFMANN, Fritz
# 15      Athens               CURTIS, Thomas
# 16      Athens           GOULDING, Grantley
# 17      Athens            LERMUSIAUX, Albin
# 18      Athens                 FLACK, Edwin
# 19      Athens                BLAKE, Arthur
# ...

# %%
oo["NOC"]
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
type(oo.NOC)
# Out:
# pandas.core.series.Series

# %%
oo[["Edition","City","Athlete","Medal"]]
# Out:
#        Edition     City                      Athlete   Medal
# 0         1896   Athens                HAJOS, Alfred    Gold
# 1         1896   Athens             HERSCHMANN, Otto  Silver
# 2         1896   Athens            DRIVAS, Dimitrios  Bronze
# 3         1896   Athens           MALOKINIS, Ioannis    Gold
# 4         1896   Athens           CHASAPIS, Spiridon  Silver
# 5         1896   Athens        CHOROPHAS, Efstathios  Bronze
# 6         1896   Athens                HAJOS, Alfred    Gold
# 7         1896   Athens             ANDREOU, Joannis  Silver
# 8         1896   Athens        CHOROPHAS, Efstathios  Bronze
# 9         1896   Athens                NEUMANN, Paul    Gold
# 10        1896   Athens            PEPANOS, Antonios  Silver
# 11        1896   Athens                LANE, Francis  Bronze
# 12        1896   Athens             SZOKOLYI, Alajos  Bronze
# 13        1896   Athens                BURKE, Thomas    Gold
# ...

# %%
oo.shape
# Out:
# (29216, 10)

# %%
oo.shape[0]
# Out:
# 29216

# %%
oo.shape[1]
# Out:
# 10

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
oo.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo.sort_values(["Medal"])
# Out:
#               City  Edition          Sport       Discipline  \
# 14607     Montreal     1976     Gymnastics      Artistic G.
# 21859      Atlanta     1996     Basketball       Basketball
# 21858      Atlanta     1996     Basketball       Basketball
# 21857      Atlanta     1996     Basketball       Basketball
# 21856      Atlanta     1996     Basketball       Basketball
# 21855      Atlanta     1996     Basketball       Basketball
# 21854      Atlanta     1996     Basketball       Basketball
# 21853      Atlanta     1996     Basketball       Basketball
# 21860      Atlanta     1996     Basketball       Basketball
# 21852      Atlanta     1996     Basketball       Basketball
# 7058        Berlin     1936         Rowing           Rowing
# 7059        Berlin     1936         Rowing           Rowing
# 7060        Berlin     1936         Rowing           Rowing
# 12106       Mexico     1968  Canoe / Kayak  Canoe / Kayak F
# 12105       Mexico     1968  Canoe / Kayak  Canoe / Kayak F
# ...

# %%
oo.Athlete.sort_values()
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
ath=oo.Athlete.sort_values()

# %%
oo.sort_values(by=["Edition","Athlete"])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo[(oo.Medal=="Gold")&(oo.Gender=="Women")]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %%
oo[oo.Athlete.str.contains("Florence")&(oo.Gender=="Women")]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
oo[oo.Athlete.str.contains("Jesse Owens")]
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []

# %%
oo[oo.Athlete.str.contains("Jesse")]
# Out:
#                         City  Edition       Sport     Discipline  \
# 1522                  London     1908      Hockey         Hockey
# 1773                  London     1908    Shooting       Shooting
# 6427                  Berlin     1936   Athletics      Athletics
# 6439                  Berlin     1936   Athletics      Athletics
# 6456                  Berlin     1936   Athletics      Athletics
# 6523                  Berlin     1936   Athletics      Athletics
# 7444                  London     1948  Basketball     Basketball
# 9070   Melbourne / Stockholm     1956   Athletics      Athletics
# 11462                  Tokyo     1964      Rowing         Rowing
# 13113                 Munich     1972      Boxing         Boxing
# 26519                 Athens     2004      Hockey         Hockey
# 27479                Beijing     2008    Aquatics     Water polo
# 28065                Beijing     2008     Cycling  Cycling Track
#
# ...

# %%
oo.sort_values(["Gender","NOC","Medal"])
# Out:
#               City  Edition       Sport  Discipline  \
# 28965      Beijing     2008   Taekwondo   Taekwondo
# 19323        Seoul     1988     Sailing     Sailing
# 17060  Los Angeles     1984      Boxing      Boxing
# 17064  Los Angeles     1984      Boxing      Boxing
# 20200    Barcelona     1992      Boxing      Boxing
# 21960      Atlanta     1996      Boxing      Boxing
# 23631       Sydney     2000   Athletics   Athletics
# 23655       Sydney     2000   Athletics   Athletics
# 23890       Sydney     2000      Boxing      Boxing
# 21610      Atlanta     1996   Athletics   Athletics
# 21946      Atlanta     1996      Boxing      Boxing
# 23624       Sydney     2000   Athletics   Athletics
# 28637      Beijing     2008        Judo        Judo
# 1146        London     1908    Aquatics    Swimming
# 1208        London     1908   Athletics   Athletics
# 1958     Stockholm     1912    Aquatics    Swimming
# 1967     Stockholm     1912    Aquatics    Swimming
# ...

# %%
Subset_data = oo[(oo.Medal=="Gold")&(oo.Gender=="Men")]

# %%
Subset_data
# Out:
#           City  Edition          Sport       Discipline  \
# 0       Athens     1896       Aquatics         Swimming
# 3       Athens     1896       Aquatics         Swimming
# 6       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 13      Athens     1896      Athletics        Athletics
# 15      Athens     1896      Athletics        Athletics
# 18      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 24      Athens     1896      Athletics        Athletics
# 27      Athens     1896      Athletics        Athletics
# 29      Athens     1896      Athletics        Athletics
# 33      Athens     1896      Athletics        Athletics
# 36      Athens     1896      Athletics        Athletics
# 40      Athens     1896      Athletics        Athletics
# 43      Athens     1896      Athletics        Athletics
# 46      Athens     1896      Athletics        Athletics
# ...

# %%
Subset_data.sort_values(["NOC",oo.Medal.value_count])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-151b5e0df83a> in <module>()
# ----> 1 Subset_data.sort_values(["NOC",oo.Medal.value_count])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_count'
